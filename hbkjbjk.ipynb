# %%
print("Hello World")
# Out:
# Hello World

# %%
import matplotlib.pyplot as plt
amount = [19,26,68,85,88,98]
day = ["m","t","w","th","f","s"]

am = [36,54,96,78,45,68]
d = ['m','t','w','th','f','s']
plt.plot(day, amount, marker="o")
plt.title("wscube tech")
plt.legend("Jodhpur")
plt.plot(d, am, marker="o")
plt.legend("Jaipur")
plt.show()
